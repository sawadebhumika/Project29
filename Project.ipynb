# %% [markdown]
# # Market Basket analysis (Frequent Item Generation, Apriori algorithm & Confidence Based Pruning. Evaluation of association rule by different measures.)

# %% [markdown]
# **Problem Statement**:  A smaller dataset that contains hypothetical transactions (baskets) from a grocery. Dataset store in 'groceries'. Perform the market basket analysis on groceries data.

# %%
import pandas as pd
import numpy as np

# %%
from mlxtend.frequent_patterns import association_rules, apriori
from mlxtend.preprocessing import TransactionEncoder

# %%
# Reading CSV file
groceries = pd.read_csv('groceries).csv') 
groceries.head()
# Out:
#     ID                Transaction
# 0  0.0         milk,bread,biscuit
# 1  1.0  bread,milk,biscuit,cereal
# 2  2.0                  bread,tea
# 3  3.0             jam,bread,milk
# 4  4.0                tea,biscuit

# %%
# Dropping unwanted rows (i.e 20 & 21)
groceries.drop([20,21],inplace=True)

# %%
groceries.head()
# Out:
#     ID                Transaction
# 0  0.0         milk,bread,biscuit
# 1  1.0  bread,milk,biscuit,cereal
# 2  2.0                  bread,tea
# 3  3.0             jam,bread,milk
# 4  4.0                tea,biscuit

# %%
# Get all the Transcactions as a list
transcactions = list(groceries['Transaction'].apply(lambda x: sorted(x.split(','))))
transcactions
# Out:
# [['biscuit', 'bread', 'milk'],
#  ['biscuit', 'bread', 'cereal', 'milk'],
#  ['bread', 'tea'],
#  ['bread', 'jam', 'milk'],
#  ['biscuit', 'tea'],
#  ['bread', 'tea'],
#  ['cereal', 'tea'],
#  ['biscuit', 'bread', 'tea'],
#  ['bread', 'jam', 'tea'],
#  ['bread', 'milk'],
#  ['biscuit', 'cereal', 'coffee', 'orange'],
#  ['biscuit', 'cereal', 'coffee', 'orange'],
#  ['coffee', 'sugar'],
#  ['bread', 'coffee', 'orange'],
#  ['biscuit', 'bread', 'sugar'],
#  ['cereal', 'coffee', 'sugar'],
#  ['biscuit', 'bread', 'sugar'],
#  ['bread', 'coffee', 'sugar'],
#  ['bread', 'coffee', 'sugar'],
#  ['cereal', 'coffee', 'milk', 'tea']]

# %%
# instantiate transcation encoder
encoder = TransactionEncoder().fit(transcactions)
onehot = encoder.transform(transcactions)

# convert one-hot encode data to DataFrame
onehot = pd.DataFrame(onehot, columns=encoder.columns_)

# %%
onehot.head()
# Out:
#    biscuit  bread  cereal  coffee    jam   milk  orange  sugar    tea
# 0     True   True   False   False  False   True   False  False  False
# 1     True   True    True   False  False   True   False  False  False
# 2    False   True   False   False  False  False   False  False   True
# 3    False   True   False   False   True   True   False  False  False
# 4     True  False   False   False  False  False   False  False   True

# %% [markdown]
# Here, we encode our data so that it could easily be fitted to a machine learning model

# %%
# compute frequent items using the Apriori algorithm - Get up to three items
frequent_itemsets = apriori(onehot, min_support = 0.001, max_len = 3, use_colnames=True)
frequent_itemsets.head()
# Out:
#    support   itemsets
# 0     0.40  (biscuit)
# 1     0.65    (bread)
# 2     0.30   (cereal)
# 3     0.40   (coffee)
# 4     0.10      (jam)

# %%
rules =  rules.sort_values('confidence',ascending = False)[:25]

# %% [markdown]
#  Support is an indication of how frequently the items appear in the data.
# And support shows that 65% of people purcahsed bread in their groceries

# %%
# compute all association rules for frequent_itemsets
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.head()
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0    (cereal)   (biscuit)                0.30                0.40     0.15
# 1   (biscuit)    (cereal)                0.40                0.30     0.15
# 2      (milk)   (biscuit)                0.25                0.40     0.10
# 3   (biscuit)      (milk)                0.40                0.25     0.10
# 4    (orange)   (biscuit)                0.15                0.40     0.10
#
#    confidence      lift  leverage  conviction
# 0    0.500000  1.250000      0.03        1.20
# 1    0.375000  1.250000      0.03        1.12
# 2    0.400000  1.000000      0.00        1.00
# 3    0.250000  1.000000      0.00        1.00
# 4    0.666667  1.666667      0.04        1.80

# %%
# To display maximum set of rows
pd.set_option('display.max_rows',500)
rules.describe
# Out:
# <bound method NDFrame.describe of            antecedents        consequents  antecedent support  \
# 0             (cereal)          (biscuit)                0.30
# 1            (biscuit)           (cereal)                0.40
# 2               (milk)          (biscuit)                0.25
# 3            (biscuit)             (milk)                0.40
# 4             (orange)          (biscuit)                0.15
# 5            (biscuit)           (orange)                0.40
# 6              (bread)              (jam)                0.65
# 7                (jam)            (bread)                0.10
# 8              (bread)             (milk)                0.65
# 9               (milk)            (bread)                0.25
# 10             (sugar)            (bread)                0.30
# 11             (bread)            (sugar)                0.65
# 12            (coffee)           (cereal)                0.40
# 13            (cereal)           (coffee)                0.30
# 14              (milk)           (cereal)                0.25
# 15            (cereal)             (milk)                0.30
# 16            (cereal)           (orange)                0.30
# 17            (orange)           (cereal)                0.15
# 18            (coffee)           (orange)                0.40
# 19            (orange)           (coffee)                0.15
# 20             (sugar)           (coffee)                0.30
# 21            (coffee)            (sugar)                0.40
# 22              (milk)              (jam)                0.25
# 23               (jam)             (milk)                0.10
# 24               (jam)              (tea)                0.10
# 25               (tea)              (jam)                0.35
# 26     (bread, cereal)          (biscuit)                0.05
# 27           (biscuit)    (bread, cereal)                0.40
# 28       (bread, milk)          (biscuit)                0.20
# 29    (bread, biscuit)             (milk)                0.25
# 30     (milk, biscuit)            (bread)                0.10
# 31             (bread)    (milk, biscuit)                0.65
# 32              (milk)   (bread, biscuit)                0.25
# 33           (biscuit)      (bread, milk)                0.40
# 34      (sugar, bread)          (biscuit)                0.20
# 35    (sugar, biscuit)            (bread)                0.10
# 36    (bread, biscuit)            (sugar)                0.25
# 37             (sugar)   (bread, biscuit)                0.30
# 38             (bread)   (sugar, biscuit)                0.65
# 39           (biscuit)     (sugar, bread)                0.40
# 40    (coffee, cereal)          (biscuit)                0.20
# 41   (coffee, biscuit)           (cereal)                0.10
# 42   (cereal, biscuit)           (coffee)                0.15
# 43            (coffee)  (cereal, biscuit)                0.40
# 44            (cereal)  (coffee, biscuit)                0.30
# 45           (biscuit)   (coffee, cereal)                0.40
# 46      (milk, cereal)          (biscuit)                0.10
# 47     (milk, biscuit)           (cereal)                0.10
# 48   (cereal, biscuit)             (milk)                0.15
# 49              (milk)  (cereal, biscuit)                0.25
# 50            (cereal)    (milk, biscuit)                0.30
# 51           (biscuit)     (milk, cereal)                0.40
# 52    (cereal, orange)          (biscuit)                0.10
# 53   (cereal, biscuit)           (orange)                0.15
# 54   (orange, biscuit)           (cereal)                0.10
# 55            (cereal)  (orange, biscuit)                0.30
# 56            (orange)  (cereal, biscuit)                0.15
# 57           (biscuit)   (cereal, orange)                0.40
# 58    (coffee, orange)          (biscuit)                0.15
# 59   (coffee, biscuit)           (orange)                0.10
# 60   (orange, biscuit)           (coffee)                0.10
# 61            (coffee)  (orange, biscuit)                0.40
# 62            (orange)  (coffee, biscuit)                0.15
# 63           (biscuit)   (coffee, orange)                0.40
# 64     (bread, cereal)             (milk)                0.05
# 65              (milk)    (bread, cereal)                0.25
# 66     (bread, coffee)           (orange)                0.15
# 67     (bread, orange)           (coffee)                0.05
# 68            (coffee)    (bread, orange)                0.40
# 69            (orange)    (bread, coffee)                0.15
# 70     (bread, coffee)            (sugar)                0.15
# 71      (sugar, bread)           (coffee)                0.20
# 72            (coffee)     (sugar, bread)                0.40
# 73             (sugar)    (bread, coffee)                0.30
# 74       (bread, milk)              (jam)                0.20
# 75        (bread, jam)             (milk)                0.10
# 76         (milk, jam)            (bread)                0.05
# 77             (bread)        (milk, jam)                0.65
# 78              (milk)       (bread, jam)                0.25
# 79               (jam)      (bread, milk)                0.10
# 80        (bread, jam)              (tea)                0.10
# 81          (tea, jam)            (bread)                0.05
# 82        (bread, tea)              (jam)                0.20
# 83               (jam)       (bread, tea)                0.10
# 84             (bread)         (tea, jam)                0.65
# 85               (tea)       (bread, jam)                0.35
# 86    (coffee, cereal)             (milk)                0.20
# 87      (coffee, milk)           (cereal)                0.05
# 88      (milk, cereal)           (coffee)                0.10
# 89            (coffee)     (milk, cereal)                0.40
# 90            (cereal)     (coffee, milk)                0.30
# 91              (milk)   (coffee, cereal)                0.25
# 92    (coffee, cereal)           (orange)                0.20
# 93    (coffee, orange)           (cereal)                0.15
# 94    (cereal, orange)           (coffee)                0.10
# 95            (coffee)   (cereal, orange)                0.40
# 96            (cereal)   (coffee, orange)                0.30
# 97            (orange)   (coffee, cereal)                0.15
# 98     (sugar, cereal)           (coffee)                0.05
# 99            (coffee)    (sugar, cereal)                0.40
# 100      (coffee, tea)           (cereal)                0.05
# 101      (cereal, tea)           (coffee)                0.10
# 102           (coffee)      (cereal, tea)                0.40
# 103           (cereal)      (coffee, tea)                0.30
# 104     (milk, cereal)              (tea)                0.10
# 105        (milk, tea)           (cereal)                0.05
# 106      (cereal, tea)             (milk)                0.10
# 107             (milk)      (cereal, tea)                0.25
# 108           (cereal)        (milk, tea)                0.30
# 109              (tea)     (milk, cereal)                0.35
# 110     (coffee, milk)              (tea)                0.05
# 111      (coffee, tea)             (milk)                0.05
# 112        (milk, tea)           (coffee)                0.05
# 113           (coffee)        (milk, tea)                0.40
# 114             (milk)      (coffee, tea)                0.25
# 115              (tea)     (coffee, milk)                0.35
#
#      consequent support  support  confidence      lift  leverage  conviction
# 0                  0.40     0.15    0.500000  1.250000    0.0300    1.200000
# 1                  0.30     0.15    0.375000  1.250000    0.0300    1.120000
# 2                  0.40     0.10    0.400000  1.000000    0.0000    1.000000
# 3                  0.25     0.10    0.250000  1.000000    0.0000    1.000000
# 4                  0.40     0.10    0.666667  1.666667    0.0400    1.800000
# 5                  0.15     0.10    0.250000  1.666667    0.0400    1.133333
# 6                  0.10     0.10    0.153846  1.538462    0.0350    1.063636
# 7                  0.65     0.10    1.000000  1.538462    0.0350         inf
# 8                  0.25     0.20    0.307692  1.230769    0.0375    1.083333
# 9                  0.65     0.20    0.800000  1.230769    0.0375    1.750000
# 10                 0.65     0.20    0.666667  1.025641    0.0050    1.050000
# 11                 0.30     0.20    0.307692  1.025641    0.0050    1.011111
# 12                 0.30     0.20    0.500000  1.666667    0.0800    1.400000
# 13                 0.40     0.20    0.666667  1.666667    0.0800    1.800000
# 14                 0.30     0.10    0.400000  1.333333    0.0250    1.166667
# 15                 0.25     0.10    0.333333  1.333333    0.0250    1.125000
# 16                 0.15     0.10    0.333333  2.222222    0.0550    1.275000
# 17                 0.30     0.10    0.666667  2.222222    0.0550    2.100000
# 18                 0.15     0.15    0.375000  2.500000    0.0900    1.360000
# 19                 0.40     0.15    1.000000  2.500000    0.0900         inf
# 20                 0.40     0.20    0.666667  1.666667    0.0800    1.800000
# 21                 0.30     0.20    0.500000  1.666667    0.0800    1.400000
# 22                 0.10     0.05    0.200000  2.000000    0.0250    1.125000
# 23                 0.25     0.05    0.500000  2.000000    0.0250    1.500000
# 24                 0.35     0.05    0.500000  1.428571    0.0150    1.300000
# 25                 0.10     0.05    0.142857  1.428571    0.0150    1.050000
# 26                 0.40     0.05    1.000000  2.500000    0.0300         inf
# 27                 0.05     0.05    0.125000  2.500000    0.0300    1.085714
# 28                 0.40     0.10    0.500000  1.250000    0.0200    1.200000
# 29                 0.25     0.10    0.400000  1.600000    0.0375    1.250000
# 30                 0.65     0.10    1.000000  1.538462    0.0350         inf
# 31                 0.10     0.10    0.153846  1.538462    0.0350    1.063636
# 32                 0.25     0.10    0.400000  1.600000    0.0375    1.250000
# 33                 0.20     0.10    0.250000  1.250000    0.0200    1.066667
# 34                 0.40     0.10    0.500000  1.250000    0.0200    1.200000
# 35                 0.65     0.10    1.000000  1.538462    0.0350         inf
# 36                 0.30     0.10    0.400000  1.333333    0.0250    1.166667
# 37                 0.25     0.10    0.333333  1.333333    0.0250    1.125000
# 38                 0.10     0.10    0.153846  1.538462    0.0350    1.063636
# 39                 0.20     0.10    0.250000  1.250000    0.0200    1.066667
# 40                 0.40     0.10    0.500000  1.250000    0.0200    1.200000
# 41                 0.30     0.10    1.000000  3.333333    0.0700         inf
# 42                 0.40     0.10    0.666667  1.666667    0.0400    1.800000
# 43                 0.15     0.10    0.250000  1.666667    0.0400    1.133333
# 44                 0.10     0.10    0.333333  3.333333    0.0700    1.350000
# 45                 0.20     0.10    0.250000  1.250000    0.0200    1.066667
# 46                 0.40     0.05    0.500000  1.250000    0.0100    1.200000
# 47                 0.30     0.05    0.500000  1.666667    0.0200    1.400000
# 48                 0.25     0.05    0.333333  1.333333    0.0125    1.125000
# 49                 0.15     0.05    0.200000  1.333333    0.0125    1.062500
# 50                 0.10     0.05    0.166667  1.666667    0.0200    1.080000
# 51                 0.10     0.05    0.125000  1.250000    0.0100    1.028571
# 52                 0.40     0.10    1.000000  2.500000    0.0600         inf
# 53                 0.15     0.10    0.666667  4.444444    0.0775    2.550000
# 54                 0.30     0.10    1.000000  3.333333    0.0700         inf
# 55                 0.10     0.10    0.333333  3.333333    0.0700    1.350000
# 56                 0.15     0.10    0.666667  4.444444    0.0775    2.550000
# 57                 0.10     0.10    0.250000  2.500000    0.0600    1.200000
# 58                 0.40     0.10    0.666667  1.666667    0.0400    1.800000
# 59                 0.15     0.10    1.000000  6.666667    0.0850         inf
# 60                 0.40     0.10    1.000000  2.500000    0.0600         inf
# 61                 0.10     0.10    0.250000  2.500000    0.0600    1.200000
# 62                 0.10     0.10    0.666667  6.666667    0.0850    2.700000
# 63                 0.15     0.10    0.250000  1.666667    0.0400    1.133333
# 64                 0.25     0.05    1.000000  4.000000    0.0375         inf
# 65                 0.05     0.05    0.200000  4.000000    0.0375    1.187500
# 66                 0.15     0.05    0.333333  2.222222    0.0275    1.275000
# 67                 0.40     0.05    1.000000  2.500000    0.0300         inf
# 68                 0.05     0.05    0.125000  2.500000    0.0300    1.085714
# 69                 0.15     0.05    0.333333  2.222222    0.0275    1.275000
# 70                 0.30     0.10    0.666667  2.222222    0.0550    2.100000
# 71                 0.40     0.10    0.500000  1.250000    0.0200    1.200000
# 72                 0.20     0.10    0.250000  1.250000    0.0200    1.066667
# 73                 0.15     0.10    0.333333  2.222222    0.0550    1.275000
# 74                 0.10     0.05    0.250000  2.500000    0.0300    1.200000
# 75                 0.25     0.05    0.500000  2.000000    0.0250    1.500000
# 76                 0.65     0.05    1.000000  1.538462    0.0175         inf
# 77                 0.05     0.05    0.076923  1.538462    0.0175    1.029167
# 78                 0.10     0.05    0.200000  2.000000    0.0250    1.125000
# 79                 0.20     0.05    0.500000  2.500000    0.0300    1.600000
# 80                 0.35     0.05    0.500000  1.428571    0.0150    1.300000
# 81                 0.65     0.05    1.000000  1.538462    0.0175         inf
# 82                 0.10     0.05    0.250000  2.500000    0.0300    1.200000
# 83                 0.20     0.05    0.500000  2.500000    0.0300    1.600000
# 84                 0.05     0.05    0.076923  1.538462    0.0175    1.029167
# 85                 0.10     0.05    0.142857  1.428571    0.0150    1.050000
# 86                 0.25     0.05    0.250000  1.000000    0.0000    1.000000
# 87                 0.30     0.05    1.000000  3.333333    0.0350         inf
# 88                 0.40     0.05    0.500000  1.250000    0.0100    1.200000
# 89                 0.10     0.05    0.125000  1.250000    0.0100    1.028571
# 90                 0.05     0.05    0.166667  3.333333    0.0350    1.140000
# 91                 0.20     0.05    0.200000  1.000000    0.0000    1.000000
# 92                 0.15     0.10    0.500000  3.333333    0.0700    1.700000
# 93                 0.30     0.10    0.666667  2.222222    0.0550    2.100000
# 94                 0.40     0.10    1.000000  2.500000    0.0600         inf
# 95                 0.10     0.10    0.250000  2.500000    0.0600    1.200000
# 96                 0.15     0.10    0.333333  2.222222    0.0550    1.275000
# 97                 0.20     0.10    0.666667  3.333333    0.0700    2.400000
# 98                 0.40     0.05    1.000000  2.500000    0.0300         inf
# 99                 0.05     0.05    0.125000  2.500000    0.0300    1.085714
# 100                0.30     0.05    1.000000  3.333333    0.0350         inf
# 101                0.40     0.05    0.500000  1.250000    0.0100    1.200000
# 102                0.10     0.05    0.125000  1.250000    0.0100    1.028571
# 103                0.05     0.05    0.166667  3.333333    0.0350    1.140000
# 104                0.35     0.05    0.500000  1.428571    0.0150    1.300000
# 105                0.30     0.05    1.000000  3.333333    0.0350         inf
# 106                0.25     0.05    0.500000  2.000000    0.0250    1.500000
# 107                0.10     0.05    0.200000  2.000000    0.0250    1.125000
# 108                0.05     0.05    0.166667  3.333333    0.0350    1.140000
# 109                0.10     0.05    0.142857  1.428571    0.0150    1.050000
# 110                0.35     0.05    1.000000  2.857143    0.0325         inf
# 111                0.25     0.05    1.000000  4.000000    0.0375         inf
# 112                0.40     0.05    1.000000  2.500000    0.0300         inf
# 113                0.05     0.05    0.125000  2.500000    0.0300    1.085714
# 114                0.05     0.05    0.200000  4.000000    0.0375    1.187500
# 115                0.05     0.05    0.142857  2.857143    0.0325    1.108333  >

# %%
rules.sort_values('confidence',ascending = False)[:25]
# Out:
#            antecedents        consequents  antecedent support  \
# 52    (cereal, orange)          (biscuit)                0.10
# 59   (coffee, biscuit)           (orange)                0.10
# 26     (bread, cereal)          (biscuit)                0.05
# 76         (milk, jam)            (bread)                0.05
# 87      (coffee, milk)           (cereal)                0.05
# 35    (sugar, biscuit)            (bread)                0.10
# 67     (bread, orange)           (coffee)                0.05
# 64     (bread, cereal)             (milk)                0.05
# 19            (orange)           (coffee)                0.15
# 94    (cereal, orange)           (coffee)                0.10
# 60   (orange, biscuit)           (coffee)                0.10
# 98     (sugar, cereal)           (coffee)                0.05
# 30     (milk, biscuit)            (bread)                0.10
# 100      (coffee, tea)           (cereal)                0.05
# 41   (coffee, biscuit)           (cereal)                0.10
# 105        (milk, tea)           (cereal)                0.05
# 7                (jam)            (bread)                0.10
# 54   (orange, biscuit)           (cereal)                0.10
# 110     (coffee, milk)              (tea)                0.05
# 111      (coffee, tea)             (milk)                0.05
# 112        (milk, tea)           (coffee)                0.05
# 81          (tea, jam)            (bread)                0.05
# 9               (milk)            (bread)                0.25
# 42   (cereal, biscuit)           (coffee)                0.15
# 56            (orange)  (cereal, biscuit)                0.15
#
#      consequent support  support  confidence      lift  leverage  conviction
# 52                 0.40     0.10    1.000000  2.500000    0.0600         inf
# 59                 0.15     0.10    1.000000  6.666667    0.0850         inf
# 26                 0.40     0.05    1.000000  2.500000    0.0300         inf
# 76                 0.65     0.05    1.000000  1.538462    0.0175         inf
# 87                 0.30     0.05    1.000000  3.333333    0.0350         inf
# 35                 0.65     0.10    1.000000  1.538462    0.0350         inf
# 67                 0.40     0.05    1.000000  2.500000    0.0300         inf
# 64                 0.25     0.05    1.000000  4.000000    0.0375         inf
# 19                 0.40     0.15    1.000000  2.500000    0.0900         inf
# 94                 0.40     0.10    1.000000  2.500000    0.0600         inf
# 60                 0.40     0.10    1.000000  2.500000    0.0600         inf
# 98                 0.40     0.05    1.000000  2.500000    0.0300         inf
# 30                 0.65     0.10    1.000000  1.538462    0.0350         inf
# 100                0.30     0.05    1.000000  3.333333    0.0350         inf
# 41                 0.30     0.10    1.000000  3.333333    0.0700         inf
# 105                0.30     0.05    1.000000  3.333333    0.0350         inf
# 7                  0.65     0.10    1.000000  1.538462    0.0350         inf
# 54                 0.30     0.10    1.000000  3.333333    0.0700         inf
# 110                0.35     0.05    1.000000  2.857143    0.0325         inf
# 111                0.25     0.05    1.000000  4.000000    0.0375         inf
# 112                0.40     0.05    1.000000  2.500000    0.0300         inf
# 81                 0.65     0.05    1.000000  1.538462    0.0175         inf
# 9                  0.65     0.20    0.800000  1.230769    0.0375        1.75
# 42                 0.40     0.10    0.666667  1.666667    0.0400        1.80
# 56                 0.15     0.10    0.666667  4.444444    0.0775        2.55

# %% [markdown]
# Confidence indicates the number of times the if-then statements are found true.
#
# We can see that there are many items for which the confidence is 100%
# For instance, if the customers that bought (biscuit, cereal) also bought orange.
# With (coffee,tea) also bought milk which seems to be obvious

# %% [markdown]
# Let’s say that we want to get the top associated rules, given that the left-hand side has two items, then which item is more likely to be added to the basket?

# %%
rules['lhs items'] = rules['antecedents'].apply(lambda x:len(x) )
rules[rules['lhs items']>1].sort_values('lift', ascending=False).head(10)
# Out:
#            antecedents consequents  antecedent support  consequent support  \
# 59   (coffee, biscuit)    (orange)                0.10                0.15
# 53   (cereal, biscuit)    (orange)                0.15                0.15
# 111      (coffee, tea)      (milk)                0.05                0.25
# 64     (bread, cereal)      (milk)                0.05                0.25
# 41   (coffee, biscuit)    (cereal)                0.10                0.30
# 54   (orange, biscuit)    (cereal)                0.10                0.30
# 87      (coffee, milk)    (cereal)                0.05                0.30
# 92    (coffee, cereal)    (orange)                0.20                0.15
# 100      (coffee, tea)    (cereal)                0.05                0.30
# 105        (milk, tea)    (cereal)                0.05                0.30
#
#      support  confidence      lift  leverage  conviction  lhs items
# 59      0.10    1.000000  6.666667    0.0850         inf          2
# 53      0.10    0.666667  4.444444    0.0775        2.55          2
# 111     0.05    1.000000  4.000000    0.0375         inf          2
# 64      0.05    1.000000  4.000000    0.0375         inf          2
# 41      0.10    1.000000  3.333333    0.0700         inf          2
# 54      0.10    1.000000  3.333333    0.0700         inf          2
# 87      0.05    1.000000  3.333333    0.0350         inf          2
# 92      0.10    0.500000  3.333333    0.0700        1.70          2
# 100     0.05    1.000000  3.333333    0.0350         inf          2
# 105     0.05    1.000000  3.333333    0.0350         inf          2

# %% [markdown]
# As we can see, if someone has already added to his basket (coffee, biscuit) or (cereal, biscuit) then the item which is more likely to be added is **orange**

# %% [markdown]
# We will show all the rules where the left-hand side consists of 2 items and we are looking for an extra one. The measurement is the lift.

# %%
# Replace frozen sets with strings
rules['antecedents_'] = rules['antecedents'].apply(lambda a: ','.join(list(a)))
rules['consequents_'] = rules['consequents'].apply(lambda a: ','.join(list(a)))
# Transform the DataFrame of rules into a matrix using the lift metric
pivot = rules[rules['lhs items']>1].pivot(index = 'antecedents_', 
                    columns = 'consequents_', values= 'lift')
pivot
# Out:
# consequents_     biscuit     bread    cereal    coffee  jam      milk  \
# antecedents_
# bread,biscuit        NaN       NaN       NaN       NaN  NaN  1.600000
# bread,cereal    2.500000       NaN       NaN       NaN  NaN  4.000000
# bread,coffee         NaN       NaN       NaN       NaN  NaN       NaN
# bread,jam            NaN       NaN       NaN       NaN  NaN  2.000000
# bread,milk      1.250000       NaN       NaN       NaN  2.5       NaN
# bread,orange         NaN       NaN       NaN  2.500000  NaN       NaN
# bread,tea            NaN       NaN       NaN       NaN  2.5       NaN
# cereal,biscuit       NaN       NaN       NaN  1.666667  NaN  1.333333
# cereal,orange   2.500000       NaN       NaN  2.500000  NaN       NaN
# cereal,tea           NaN       NaN       NaN  1.250000  NaN  2.000000
# coffee,biscuit       NaN       NaN  3.333333       NaN  NaN       NaN
# coffee,cereal   1.250000       NaN       NaN       NaN  NaN  1.000000
# coffee,milk          NaN       NaN  3.333333       NaN  NaN       NaN
# coffee,orange   1.666667       NaN  2.222222       NaN  NaN       NaN
# coffee,tea           NaN       NaN  3.333333       NaN  NaN  4.000000
# milk,biscuit         NaN  1.538462  1.666667       NaN  NaN       NaN
# milk,cereal     1.250000       NaN       NaN  1.250000  NaN       NaN
# milk,jam             NaN  1.538462       NaN       NaN  NaN       NaN
# milk,tea             NaN       NaN  3.333333  2.500000  NaN       NaN
# orange,biscuit       NaN       NaN  3.333333  2.500000  NaN       NaN
# sugar,biscuit        NaN  1.538462       NaN       NaN  NaN       NaN
# sugar,bread     1.250000       NaN       NaN  1.250000  NaN       NaN
# sugar,cereal         NaN       NaN       NaN  2.500000  NaN       NaN
# tea,jam              NaN  1.538462       NaN       NaN  NaN       NaN
#
# consequents_      orange     sugar       tea
# antecedents_
# bread,biscuit        NaN  1.333333       NaN
# bread,cereal         NaN       NaN       NaN
# bread,coffee    2.222222  2.222222       NaN
# bread,jam            NaN       NaN  1.428571
# bread,milk           NaN       NaN       NaN
# bread,orange         NaN       NaN       NaN
# bread,tea            NaN       NaN       NaN
# cereal,biscuit  4.444444       NaN       NaN
# cereal,orange        NaN       NaN       NaN
# cereal,tea           NaN       NaN       NaN
# coffee,biscuit  6.666667       NaN       NaN
# coffee,cereal   3.333333       NaN       NaN
# coffee,milk          NaN       NaN  2.857143
# coffee,orange        NaN       NaN       NaN
# coffee,tea           NaN       NaN       NaN
# milk,biscuit         NaN       NaN       NaN
# milk,cereal          NaN       NaN  1.428571
# milk,jam             NaN       NaN       NaN
# milk,tea             NaN       NaN       NaN
# orange,biscuit       NaN       NaN       NaN
# sugar,biscuit        NaN       NaN       NaN
# sugar,bread          NaN       NaN       NaN
# sugar,cereal         NaN       NaN       NaN
# tea,jam              NaN       NaN       NaN

# %% [markdown]
# Lift > 1 ,implies that there is a positive relationship for the corresponding antecedent and consequent

# %% [markdown]
# **Problem Statement**: Consider the 'Online retail II' dataset. This Online Retail II data set contains all the transactions occurring for a UK-based and registered, non-store online retail between 01/12/2009 and 09/12/2011. The company mainly sells unique all-occasion gift-ware. Many customers of the company are wholesalers. Perform the Market Basket Analysis on this data.

# %% [markdown]
# **Data Set Information:**
#
# This Online Retail II data set contains all the transactions occurring for a UK-based and registered, non-store online retail between 01/12/2009 and 09/12/2011.The company mainly sells unique all-occasion gift-ware. Many customers of the company are wholesalers.
#
# **Attribute Information:**
#
# 1) InvoiceNo: Invoice number. Nominal. A 6-digit integral number uniquely assigned to each transaction. If this code starts with the letter 'c', it indicates a cancellation.
#
# 2)StockCode: Product (item) code. Nominal. A 5-digit integral number uniquely assigned to each distinct product.
#
# 3)Description: Product (item) name. Nominal.
#
# 4)Quantity: The quantities of each product (item) per transaction. Numeric.
#
# 5)InvoiceDate: Invice date and time. Numeric. The day and time when a transaction was generated.
#
# 6)UnitPrice: Unit price. Numeric. Product price per unit in sterling (Â£).
#
# 7)CustomerID: Customer number. Nominal. A 5-digit integral number uniquely assigned to each customer.
#
# 8)Country: Country name. Nominal. The name of the country where a customer resides.

# %%
data=pd.read_csv('/content/online_retail_II (1).csv',encoding='ISO-8859-1')
data.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1  536365     71053                  WHITE METAL LANTERN       6.0
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#         InvoiceDate  Price  Customer ID         Country
# 0  01-12-2010 08:26   2.55      17850.0  United Kingdom
# 1  01-12-2010 08:26   3.39      17850.0  United Kingdom
# 2  01-12-2010 08:26   2.75      17850.0  United Kingdom
# 3  01-12-2010 08:26   3.39      17850.0  United Kingdom
# 4  01-12-2010 08:26   3.39      17850.0  United Kingdom

# %% [markdown]
# As you can see, this datasets contains 8 features with 541909 rows. It shows us the transaction of an actual online retail in UK from 1 December 2010 until 9 December 2011. So, it is a whole year transaction data from an actual online retail business.

# %%
# Structure of the data
data=data.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 272706 entries, 0 to 370510
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      272706 non-null  object
#  1   StockCode    272706 non-null  object
#  2   Description  272706 non-null  object
#  3   Quantity     272706 non-null  float64
#  4   InvoiceDate  272706 non-null  object
#  5   Price        272706 non-null  float64
#  6   Customer ID  272706 non-null  float64
#  7   Country      272706 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 18.7+ MB

# %% [markdown]
# After dropping the NA the entries now is decreased to 406830 entries (24.9%). It means, there are around 24% from all rows that contain at least one missing values.

# %%
# No. of missing values in each column
data.isna().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
data_plus=data[data['Quantity']>=0]
data_plus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 266349 entries, 0 to 370510
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      266349 non-null  object
#  1   StockCode    266349 non-null  object
#  2   Description  266349 non-null  object
#  3   Quantity     266349 non-null  float64
#  4   InvoiceDate  266349 non-null  object
#  5   Price        266349 non-null  float64
#  6   Customer ID  266349 non-null  float64
#  7   Country      266349 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 18.3+ MB

# %% [markdown]
# In this datasets, the Quantity column shows us the number of items that are bought in each transaction (InvoiceNo). Sometimes, the transaction gets cancelled, because this is an online retail. When there is a cancellation on a particular transaction, it will be datificated in Quantity column as a negative value. Since we’re doing market basket analysis, we basically would like to analyze what’s inside the basket that our customer actually bought. This negative value is not one of them. That is why we’re not going to use them. As you can see in the picture above, there are only 397925 entries that are not cancelled.

# %%
#Create the Basket Data while Using The Transaction From UK Only
basket_plus=(data_plus[data_plus['Country']=='United Kingdom'].groupby(['Invoice','Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('Invoice'))
basket_plus
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# Invoice
# 536365                                  0.0                             0.0
# 536366                                  0.0                             0.0
# 536367                                  0.0                             0.0
# 536368                                  0.0                             0.0
# 536369                                  0.0                             0.0
# ...                                     ...                             ...
# 569132                                  0.0                             0.0
# 569133                                  0.0                             0.0
# 569134                                  0.0                             0.0
# 569136                                  0.0                             0.0
# 569139                                  0.0                             0.0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# Invoice
# 536365                      0.0                           0.0
# 536366                      0.0                           0.0
# 536367                      0.0                           0.0
# 536368                      0.0                           0.0
# 536369                      0.0                           0.0
# ...                         ...                           ...
# 569132                      0.0                           0.0
# 569133                      0.0                           0.0
# 569134                      0.0                           0.0
# 569136                      0.0                           0.0
# 569139                      0.0                           0.0
#
# Description   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# Invoice
# 536365                               0.0                       0.0
# 536366                               0.0                       0.0
# 536367                               0.0                       0.0
# 536368                               0.0                       0.0
# 536369                               0.0                       0.0
# ...                                  ...                       ...
# 569132                               0.0                       0.0
# 569133                               0.0                       0.0
# 569134                               0.0                       0.0
# 569136                               0.0                       0.0
# 569139                               0.0                       0.0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# Invoice
# 536365                                    0.0                      0.0
# 536366                                    0.0                      0.0
# 536367                                    0.0                      0.0
# 536368                                    0.0                      0.0
# 536369                                    0.0                      0.0
# ...                                       ...                      ...
# 569132                                    0.0                      0.0
# 569133                                    0.0                      0.0
# 569134                                    0.0                      0.0
# 569136                                    0.0                      0.0
# 569139                                    0.0                      0.0
#
# Description   TOADSTOOL BEDSIDE LIGHT    TRELLIS COAT RACK  ...  \
# Invoice                                                     ...
# 536365                             0.0                 0.0  ...
# 536366                             0.0                 0.0  ...
# 536367                             0.0                 0.0  ...
# 536368                             0.0                 0.0  ...
# 536369                             0.0                 0.0  ...
# ...                                ...                 ...  ...
# 569132                             0.0                 0.0  ...
# 569133                             0.0                 0.0  ...
# 569134                             0.0                 0.0  ...
# 569136                             0.0                 0.0  ...
# 569139                             0.0                 0.0  ...
#
# Description  ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# Invoice
# 536365                             0.0                        0.0
# 536366                             0.0                        0.0
# 536367                             0.0                        0.0
# 536368                             0.0                        0.0
# 536369                             0.0                        0.0
# ...                                ...                        ...
# 569132                             0.0                        0.0
# 569133                             0.0                        0.0
# 569134                             0.0                        0.0
# 569136                             0.0                        0.0
# 569139                             0.0                        0.0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# Invoice
# 536365                                    0.0                             0.0
# 536366                                    0.0                             0.0
# 536367                                    0.0                             0.0
# 536368                                    0.0                             0.0
# 536369                                    0.0                             0.0
# ...                                       ...                             ...
# 569132                                    0.0                             0.0
# 569133                                    0.0                             0.0
# 569134                                    0.0                             0.0
# 569136                                    0.0                             0.0
# 569139                                    0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# Invoice
# 536365                                   0.0                              0.0
# 536366                                   0.0                              0.0
# 536367                                   0.0                              0.0
# 536368                                   0.0                              0.0
# 536369                                   0.0                              0.0
# ...                                      ...                              ...
# 569132                                   0.0                              0.0
# 569133                                   0.0                              0.0
# 569134                                   0.0                              0.0
# 569136                                   0.0                              0.0
# 569139                                   0.0                              0.0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# Invoice
# 536365                                  0.0                               0.0
# 536366                                  0.0                               0.0
# 536367                                  0.0                               0.0
# 536368                                  0.0                               0.0
# 536369                                  0.0                               0.0
# ...                                     ...                               ...
# 569132                                  0.0                               0.0
# 569133                                  0.0                               0.0
# 569134                                  0.0                               0.0
# 569136                                  0.0                               0.0
# 569139                                  0.0                               0.0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# Invoice
# 536365                               0.0                               0.0
# 536366                               0.0                               0.0
# 536367                               0.0                               0.0
# 536368                               0.0                               0.0
# 536369                               0.0                               0.0
# ...                                  ...                               ...
# 569132                               0.0                               0.0
# 569133                               0.0                               0.0
# 569134                               0.0                               0.0
# 569136                               0.0                               0.0
# 569139                               0.0                               0.0
#
# [11843 rows x 3627 columns]

# %% [markdown]
# Using the positive-quantity-and-the-transaction-from-UK-only data, we grouped the data by the transaction (InvoiveNo) & the items (Description) and showed the values ​​of Quantity of each item bought. After that we sum up the value and unstack it. Lastly we changed the index of the data frame to the InvoiceNo so that we could see the quantity of each item bought per InvoiceNo. This dataframe is basically the ‘basket’ that our customers ‘carry on’ to the cashier in our shop. It shows us how much this customer / transaction (InvoiveNo) bought a particular item. If the number is 0, then this customer didn’t buy that particular item. If it shows another value (12 for instances), it means that the customer has bought as many as 12 items.

# %%
 #Encode The Data

# %% [markdown]
# In market basket analysis, the number of each item bought is not really important. The important one is whether an item is bought or not. Because, we only would like to know, what is the association of buying some items and buying some others. So, we need to encode the basket data into a binary data that shows whether an items is bought (1) or not (0).

# %%
def encode_units(x):
  if x<=0:
    return 0
  if x>=1:
    return 1

basket_encode_plus=basket_plus.applymap(encode_units)
basket_encode_plus
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# Invoice
# 536365                                    0                               0
# 536366                                    0                               0
# 536367                                    0                               0
# 536368                                    0                               0
# 536369                                    0                               0
# ...                                     ...                             ...
# 569132                                    0                               0
# 569133                                    0                               0
# 569134                                    0                               0
# 569136                                    0                               0
# 569139                                    0                               0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# Invoice
# 536365                        0                             0
# 536366                        0                             0
# 536367                        0                             0
# 536368                        0                             0
# 536369                        0                             0
# ...                         ...                           ...
# 569132                        0                             0
# 569133                        0                             0
# 569134                        0                             0
# 569136                        0                             0
# 569139                        0                             0
#
# Description   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# Invoice
# 536365                                 0                         0
# 536366                                 0                         0
# 536367                                 0                         0
# 536368                                 0                         0
# 536369                                 0                         0
# ...                                  ...                       ...
# 569132                                 0                         0
# 569133                                 0                         0
# 569134                                 0                         0
# 569136                                 0                         0
# 569139                                 0                         0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# Invoice
# 536365                                      0                        0
# 536366                                      0                        0
# 536367                                      0                        0
# 536368                                      0                        0
# 536369                                      0                        0
# ...                                       ...                      ...
# 569132                                      0                        0
# 569133                                      0                        0
# 569134                                      0                        0
# 569136                                      0                        0
# 569139                                      0                        0
#
# Description   TOADSTOOL BEDSIDE LIGHT    TRELLIS COAT RACK  ...  \
# Invoice                                                     ...
# 536365                               0                   0  ...
# 536366                               0                   0  ...
# 536367                               0                   0  ...
# 536368                               0                   0  ...
# 536369                               0                   0  ...
# ...                                ...                 ...  ...
# 569132                               0                   0  ...
# 569133                               0                   0  ...
# 569134                               0                   0  ...
# 569136                               0                   0  ...
# 569139                               0                   0  ...
#
# Description  ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# Invoice
# 536365                               0                          0
# 536366                               0                          0
# 536367                               0                          0
# 536368                               0                          0
# 536369                               0                          0
# ...                                ...                        ...
# 569132                               0                          0
# 569133                               0                          0
# 569134                               0                          0
# 569136                               0                          0
# 569139                               0                          0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# Invoice
# 536365                                      0                               0
# 536366                                      0                               0
# 536367                                      0                               0
# 536368                                      0                               0
# 536369                                      0                               0
# ...                                       ...                             ...
# 569132                                      0                               0
# 569133                                      0                               0
# 569134                                      0                               0
# 569136                                      0                               0
# 569139                                      0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# Invoice
# 536365                                     0                                0
# 536366                                     0                                0
# 536367                                     0                                0
# 536368                                     0                                0
# 536369                                     0                                0
# ...                                      ...                              ...
# 569132                                     0                                0
# 569133                                     0                                0
# 569134                                     0                                0
# 569136                                     0                                0
# 569139                                     0                                0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# Invoice
# 536365                                    0                                 0
# 536366                                    0                                 0
# 536367                                    0                                 0
# 536368                                    0                                 0
# 536369                                    0                                 0
# ...                                     ...                               ...
# 569132                                    0                                 0
# 569133                                    0                                 0
# 569134                                    0                                 0
# 569136                                    0                                 0
# 569139                                    0                                 0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# Invoice
# 536365                                 0                                 0
# 536366                                 0                                 0
# 536367                                 0                                 0
# 536368                                 0                                 0
# 536369                                 0                                 0
# ...                                  ...                               ...
# 569132                                 0                                 0
# 569133                                 0                                 0
# 569134                                 0                                 0
# 569136                                 0                                 0
# 569139                                 0                                 0
#
# [11843 rows x 3627 columns]

# %% [markdown]
# This way, we generated a data frame that shows us whether a particular items is bought or not.

# %% [markdown]
# Filter The Transaction : Bought More Than 1 Items Only
#
# In market basket analysis, we are going to uncover the association between 2 or more items that is bought according to historical data. So, it is less useful if a transaction only bought a single items. I mean, how could we uncover the association between 2 or more items if there is only 1 item bought? Hence, the next step is to filter out the transactions that is bought more than 1 item

# %%
basket_filter_plus=basket_encode_plus[(basket_encode_plus>0).sum(axis=1)>=2]
basket_filter_plus
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# Invoice
# 536365                                    0                               0
# 536366                                    0                               0
# 536367                                    0                               0
# 536368                                    0                               0
# 536372                                    0                               0
# ...                                     ...                             ...
# 569132                                    0                               0
# 569133                                    0                               0
# 569134                                    0                               0
# 569136                                    0                               0
# 569139                                    0                               0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# Invoice
# 536365                        0                             0
# 536366                        0                             0
# 536367                        0                             0
# 536368                        0                             0
# 536372                        0                             0
# ...                         ...                           ...
# 569132                        0                             0
# 569133                        0                             0
# 569134                        0                             0
# 569136                        0                             0
# 569139                        0                             0
#
# Description   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# Invoice
# 536365                                 0                         0
# 536366                                 0                         0
# 536367                                 0                         0
# 536368                                 0                         0
# 536372                                 0                         0
# ...                                  ...                       ...
# 569132                                 0                         0
# 569133                                 0                         0
# 569134                                 0                         0
# 569136                                 0                         0
# 569139                                 0                         0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# Invoice
# 536365                                      0                        0
# 536366                                      0                        0
# 536367                                      0                        0
# 536368                                      0                        0
# 536372                                      0                        0
# ...                                       ...                      ...
# 569132                                      0                        0
# 569133                                      0                        0
# 569134                                      0                        0
# 569136                                      0                        0
# 569139                                      0                        0
#
# Description   TOADSTOOL BEDSIDE LIGHT    TRELLIS COAT RACK  ...  \
# Invoice                                                     ...
# 536365                               0                   0  ...
# 536366                               0                   0  ...
# 536367                               0                   0  ...
# 536368                               0                   0  ...
# 536372                               0                   0  ...
# ...                                ...                 ...  ...
# 569132                               0                   0  ...
# 569133                               0                   0  ...
# 569134                               0                   0  ...
# 569136                               0                   0  ...
# 569139                               0                   0  ...
#
# Description  ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# Invoice
# 536365                               0                          0
# 536366                               0                          0
# 536367                               0                          0
# 536368                               0                          0
# 536372                               0                          0
# ...                                ...                        ...
# 569132                               0                          0
# 569133                               0                          0
# 569134                               0                          0
# 569136                               0                          0
# 569139                               0                          0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# Invoice
# 536365                                      0                               0
# 536366                                      0                               0
# 536367                                      0                               0
# 536368                                      0                               0
# 536372                                      0                               0
# ...                                       ...                             ...
# 569132                                      0                               0
# 569133                                      0                               0
# 569134                                      0                               0
# 569136                                      0                               0
# 569139                                      0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# Invoice
# 536365                                     0                                0
# 536366                                     0                                0
# 536367                                     0                                0
# 536368                                     0                                0
# 536372                                     0                                0
# ...                                      ...                              ...
# 569132                                     0                                0
# 569133                                     0                                0
# 569134                                     0                                0
# 569136                                     0                                0
# 569139                                     0                                0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# Invoice
# 536365                                    0                                 0
# 536366                                    0                                 0
# 536367                                    0                                 0
# 536368                                    0                                 0
# 536372                                    0                                 0
# ...                                     ...                               ...
# 569132                                    0                                 0
# 569133                                    0                                 0
# 569134                                    0                                 0
# 569136                                    0                                 0
# 569139                                    0                                 0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# Invoice
# 536365                                 0                                 0
# 536366                                 0                                 0
# 536367                                 0                                 0
# 536368                                 0                                 0
# 536372                                 0                                 0
# ...                                  ...                               ...
# 569132                                 0                                 0
# 569133                                 0                                 0
# 569134                                 0                                 0
# 569136                                 0                                 0
# 569139                                 0                                 0
#
# [10912 rows x 3627 columns]

# %% [markdown]
# According to the result above, we could see that there are 15376 transaction that bought more than 1 items. It means, 92.35 % of the basket data is a transaction that is bought more than 1 item.

# %% [markdown]
# After generating the dataset above, it is now the time for us to use the apriori algorithm. Apriori algorithm is simply used to find the frequently bought items in the dataset.

# %%
# compute frequent items using the Apriori algorithm - Get up to three items
frequent_itemsets_plus = apriori(basket_filter_plus, min_support = 0.03, use_colnames=True).sort_values('support',ascending=False).reset_index(drop=True)
frequent_itemsets_plus['length']=frequent_itemsets_plus['itemsets'].apply(lambda x:len(x))
frequent_itemsets_plus

# %% [markdown]
# As you can see that there are 108 transaction that is consider as a frequently bought items. It is shown in the picture that White hanging Heart T-Light Holder is the most frequently bought items with the support value of 0.121358.

# %% [markdown]
# **Finding The Association Between Frequently Bought Items**
#
# After applying the apriori algorithm and finding the frequently bought item, it is now the time for us to apply the association rules. From association rules, we could extract information and even discover knowledge about which items that is more effective to be sold together.

# %%
rule=association_rules(frequent_itemsets_plus, metric="lift", min_threshold=1).sort_values('lift', ascending=False).reset_index(drop=True)
rule.head()
# Out:
#                            antecedents                          consequents  \
# 0    (GREEN REGENCY TEACUP AND SAUCER)   (ROSES REGENCY TEACUP AND SAUCER )
# 1   (ROSES REGENCY TEACUP AND SAUCER )    (GREEN REGENCY TEACUP AND SAUCER)
# 2  (WOODEN PICTURE FRAME WHITE FINISH)        (WOODEN FRAME ANTIQUE WHITE )
# 3        (WOODEN FRAME ANTIQUE WHITE )  (WOODEN PICTURE FRAME WHITE FINISH)
# 4                (LUNCH BAG CARS BLUE)            (LUNCH BAG PINK POLKADOT)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.045546            0.049762  0.035740    0.784708  15.769312
# 1            0.049762            0.045546  0.035740    0.718232  15.769312
# 2            0.060576            0.050495  0.030242    0.499244   9.887016
# 3            0.050495            0.060576  0.030242    0.598911   9.887016
# 4            0.063691            0.063233  0.030242    0.474820   7.509040
#
#    leverage  conviction
# 0  0.033474    4.413724
# 1  0.033474    3.387375
# 2  0.027183    1.896142
# 3  0.027183    2.342185
# 4  0.026215    1.783707

# %% [markdown]
# From the association_rules results above, we could see that ROSES REGENCY TEACUP AND SAUCER and GREEN REGENCY TEACUP AND SAUCER are the items that has the highest association each other since these two items has the highest “lift” value. The higher the lift value, the higher the association between the items willl. If the lift value is more than 1, it is enough for us to say that those two items are associated each other. In thise case, the highest value is 17.717 which is very high. It means these 2 items are very good to be sold together.

# %% [markdown]
# Beside that, we could also see the support value of ROSES REGENCY TEACUP AND SAUCER and GREEN REGENCY TEACUP AND SAUCER are 0.0309% which means there are 3.09% out of total transaction that these 2 items were sold together.

# %% [markdown]
# From the confidence, we could even extract more information. Remember that the confidence value is influenced by the antecedent and consequent. If the antecedent is higher than the consequent, then the rule that will be applied is rule number 1 (not number 2). vice versa. In this case, the antecedent value is higher than the consequent value. It means we will apply rule number 1 which is 𝐺𝑅𝐸𝐸𝑁 𝑅𝐸𝐺𝐸𝑁𝐶𝑌 𝑇𝐸𝐴𝐶𝑈𝑃 𝐴𝑁𝐷 𝑆𝐴𝑈𝐶𝐸𝑅 → 𝑅𝑂𝑆𝐸𝑆 𝑅𝐸𝐺𝐸𝑁𝐶𝑌 𝑇𝐸𝐴𝐶𝑈𝑃 𝐴𝑁𝐷 𝑆𝐴𝑈𝐶𝐸. In a more detail explanation, it means that a customer will tends to bought Roses Regency Teacup and Saucer AFTER they bought Green Regency Teacup And Saucer. Not in the other way around. This could be a very valuable information, because we are now aware which products should we put the discounts on. We could give a discounts on Roses Regency Teacup and Sauce if a customer buy Green Regency Teacup and Saucer.

# %% [markdown]
# # **Conclusion:**
# The result of this market basket analysis could be used for a data-driven marketing strategy and decision making.
#
# **Item Placements.**: We could put ROSES REGENCY TEACUP AND SAUCER and GREEN REGENCY TEACUP AND SAUCER in a closer place, maybe in a same shelf or any other closer place.
#
# **Products Bundling:** We could put ROSES REGENCY TEACUP AND SAUCER and GREEN REGENCY TEACUP AND SAUCER as a single bundle of product with a lower price compare to each price combined. This way will attract more sales and generates more income.
#
# **Customer Recommendation and Discounts:** We could put Roses Regency Teacup and Saucer in the cashier, so that every time a customer bought Green Regency Teacup and Saucer, we could offer and recommend them to buy Roses Regency Teacup and Saucer with a lower price.

# %% [markdown]
# **Problem Satement**: In this implementation, we have used the Market Basket Optimization dataset. This dataset comprises the list of transactions of a retail company over the period of one week. It contains a total of 7501 transaction records where each record consists of the list of items sold in one transaction. Using this record of transactions and items in each transaction, find the association rules between items.

# %%
dataset = pd.read_csv('/content/Market_Basket_Optimisation.csv',header=None)
dataset.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
#Getting the list of transactions from the dataset
transactions = []
for i in range(0, 7501):
    transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %%
transactions

# %% [markdown]
# Now once we are ready with the list of items in our training set, we need to run the apriori algorithm which will learn the list of association rules from the training set. Suppose we want to find the association of items with a product which is sold at least 3 times a day. So, the minimum support here will be 3 items per day multiplied by 7 days of weak and divided by the total number of transactions. That means (3*7)/7501 =  0.00279. So the equivalent 0.003 is taken here as support. Now let us we are looking for a 30% confidence in the association rule so we have kept 0.3 as the minimum confidence. The minimum lift is taken as 3 and the minimum length is considered as 2 because we want to find an association between a minimum of two items. These hyperparameters can be tuned depending on the business requirements.

# %%
pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: apyori in /usr/local/lib/python3.8/dist-packages (1.1.2)

# %%
from apyori import apriori

# %%
# Training Apriori algorithm on the dataset
rule_list = apriori(transactions, min_support = 0.003,min_confidence = 0.3, min_lift = 3, min_length = 2)
rule_list
# Out:
# <generator object apriori at 0x7f4d080867b0>

# %% [markdown]
# After executing the above line of code, we have generated the list of association rules between the items of the retail.

# %%
# Visualizing the list of rules
results = list(rule_list)
for i in results:
    print('\n')
    print(i)
    print('**********')

# %% [markdown]
# The first rule indicates an association between mushroom cream sauce and escalope with a confidence of 30%. The next rule shows an association between escalope and pasta with a confidence of 37.28%.
